# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import re

# %% [markdown]
# ### Gun Ownership & Licenses

# %% [markdown]
# source: https://www.cbsnews.com/pictures/gun-ownership-rates-by-state/

# %%
url = "https://www.cbsnews.com/pictures/gun-ownership-rates-by-state/"
response = requests.get(url)

# %%
soup = bs(response.text, 'html.parser')

# print(soup.prettify())

# %%
# Pull Section with needed data
country= soup.find_all(class_="content__body content__section")

# %%
# Drop the introduction section of article to just get paragraphs w state info
states=country[1:]
# states

# %%
# Create empty lists to hold values 
name =[]
rank=[]
count=[]
percent=[]

for x in range(2,53):
    #find each section that hold state data- easiest to find id using numbered id of html  
    state= soup.find(class_="content__body content__section", id="content__section-" + str(x))
    
    #remove headline text which is state name and ranking
    namerank=state.find('h2', class_="content__section-headline").text
    nr=namerank.split('. ')
    nr1=nr[1]
    nr0=nr[0]
    #first bolded text is number of gun licenses purchased 2021 
    lisc=state.find('strong').text
    lisc2=re.split(': ', lisc, 1)
    lisc3=lisc2[1]
    
    #second paragraph includes % of estimated guns in house in state
    pct=state.find_all('p')[1].text
    #only take percentages from this paragraph
    pct2= re.findall('\d\d.\d%|.\d%', pct)
        
    #append to lists above
    name.append(nr1)
    rank.append(nr0)
    count.append(lisc3)
    percent.append(pct2)

# %%
#Create new DF
gundata=pd.DataFrame({'State': name, 'gun_license_ct':count, 'gun_house_pct':percent})
#RAND was nested list with one item, so explode it out
gundata['gun_house_pct']=gundata['gun_house_pct'].explode()
gundata.head()
# Out:
#           State gun_license_ct gun_house_pct
# 0  Rhode Island          4,887         14.8%
# 1      Delaware          6,092         34.4%
# 2        Hawaii          9,280         14.9%
# 3       Vermont          9,451         50.5%
# 4         Maine         21,396         46.8%

# %%
#Strip formatting & convert to numeric
gundata['gun_license_ct']=gundata['gun_license_ct'].str.replace(',', '').astype(int)
gundata['gun_house_pct']=gundata['gun_house_pct'].str.replace('%', '').astype(float)

# %%
#Rank with lowest license and household percent as highest points 
gundata['gun_license_ct_rank']=gundata['gun_license_ct'].rank(method='min', na_option='bottom').astype(int)
gundata['gun_house_pct_rank']=gundata['gun_house_pct'].rank(method='min', na_option='bottom').astype(int)

# %%
gundata.head()
# Out:
#           State  gun_license_ct  gun_house_pct  gun_license_ct_rank  \
# 0  Rhode Island            4887           14.8                    1
# 1      Delaware            6092           34.4                    2
# 2        Hawaii            9280           14.9                    3
# 3       Vermont            9451           50.5                    4
# 4         Maine           21396           46.8                    5
#
#    gun_house_pct_rank
# 0                   3
# 1                  10
# 2                   4
# 3                  35
# 4                  28

# %% [markdown]
# ### Gun Mortality 2020

# %% [markdown]
# source: https://www.cdc.gov/nchs/pressroom/sosmap/firearm_mortality/firearm.htm

# %%
gun_mort=pd.read_csv('csv_s/gun_mortaility.csv')
gun_mort.head()
# Out:
#    YEAR STATE  RATE  DEATHS                                       URL
# 0  2020    AL  23.6    1141     /nchs/pressroom/states/alabama/al.htm
# 1  2020    AK  23.5     175      /nchs/pressroom/states/alaska/ak.htm
# 2  2020    AZ  16.7    1265     /nchs/pressroom/states/arizona/az.htm
# 3  2020    AR  22.6     673    /nchs/pressroom/states/arkansas/ar.htm
# 4  2020    CA   8.5    3449  /nchs/pressroom/states/california/ca.htm

# %%
#narrow to 2020 drop unnecessary columns
gun_mort20=gun_mort[gun_mort['YEAR']==2020].drop(columns={'YEAR', 'URL'}).rename(columns={'RATE': 'gun_mort_rate', 'DEATHS': 'gun_deaths'})
#ranking 
gun_mort20['gun_mort_rank'] = gun_mort20['gun_mort_rate'].rank(method='min', na_option='bottom').astype(int)
gun_mort20['gun_deaths_rank'] = gun_mort20['gun_deaths'].rank(method='min', na_option='bottom').astype(int)

# %%
gun_mort20.head()
# Out:
#   STATE  gun_mort_rate  gun_deaths  gun_mort_rank  gun_deaths_rank
# 0    AL           23.6        1141             46               35
# 1    AK           23.5         175             45               10
# 2    AZ           16.7        1265             31               39
# 3    AR           22.6         673             43               25
# 4    CA            8.5        3449              7               49

# %%
#bring in state names to exchange for abbv 
states=pd.read_csv('csv_s/state_abbv.csv')
states.head()
# Out:
#         State Abbv Region
# 0     Alabama   AL  South
# 1      Alaska   AK   West
# 2     Arizona   AZ   West
# 3    Arkansas   AR  South
# 4  California   CA   West

# %%
#merge & drop redundant columns
mort=gun_mort20.merge(states, how='outer', left_on='STATE', right_on='Abbv').drop(columns=['STATE', 'Abbv'])
mort.head()
# Out:
#    gun_mort_rate  gun_deaths  gun_mort_rank  gun_deaths_rank       State  \
# 0           23.6      1141.0           46.0             35.0     Alabama
# 1           23.5       175.0           45.0             10.0      Alaska
# 2           16.7      1265.0           31.0             39.0     Arizona
# 3           22.6       673.0           43.0             25.0    Arkansas
# 4            8.5      3449.0            7.0             49.0  California
#
#   Region
# 0  South
# 1   West
# 2   West
# 3  South
# 4   West

# %% [markdown]
# ### Merge Licence/Ownership with Mortality

# %%
gun2=gundata.merge(mort, how='outer', left_on='State', right_on='State')
gun2.head()
# Out:
#           State  gun_license_ct  gun_house_pct  gun_license_ct_rank  \
# 0  Rhode Island            4887           14.8                    1
# 1      Delaware            6092           34.4                    2
# 2        Hawaii            9280           14.9                    3
# 3       Vermont            9451           50.5                    4
# 4         Maine           21396           46.8                    5
#
#    gun_house_pct_rank  gun_mort_rate  gun_deaths  gun_mort_rank  \
# 0                   3            5.1        54.0            4.0
# 1                  10           14.4       135.0           26.0
# 2                   4            3.4        50.0            1.0
# 3                  35           11.6        76.0           14.0
# 4                  28           10.4       153.0           11.0
#
#    gun_deaths_rank     Region
# 0              2.0  Northeast
# 1              7.0  Northeast
# 2              1.0       West
# 3              3.0  Northeast
# 4              8.0  Northeast

# %% [markdown]
# ### Mass Shootings 2020
#
# source: https://www.gunviolencearchive.org/reports/number-of-gun-deaths?year=2021

# %%
mass=pd.read_csv('csv_s/gva_export.csv', usecols=['Incident Date', 'State', '# Killed', '# Injured'])
mass.head()
# Out:
#   Incident Date       State  # Killed  # Injured
# 0     12-Jun-22  California         3          4
# 1     12-Jun-22    Michigan         0          4
# 2     12-Jun-22     Indiana         2          4
# 3     12-Jun-22     Indiana         0          5
# 4     12-Jun-22       Texas         1          3

# %%
#break out the d/m/y to filter 
mass[['Day', 'Month', 'Year']]= mass['Incident Date'].str.split('-', expand=True)
#set types to do computaions
mass['mass_injured']=mass['# Injured'].astype(int)
mass['mass_killed']=mass['# Killed'].astype(int)
mass['Year']=mass['Year'].astype(int)
mass.head()
# Out:
#   Incident Date       State  # Killed  # Injured Day Month  Year  \
# 0     12-Jun-22  California         3          4  12   Jun    22
# 1     12-Jun-22    Michigan         0          4  12   Jun    22
# 2     12-Jun-22     Indiana         2          4  12   Jun    22
# 3     12-Jun-22     Indiana         0          5  12   Jun    22
# 4     12-Jun-22       Texas         1          3  12   Jun    22
#
#    mass_injured  mass_killed
# 0             4            3
# 1             4            0
# 2             4            2
# 3             5            0
# 4             3            1

# %%
# filter just to 2020
mass=mass[(mass.Year == 20)]
#drop unneeded columns
mass=mass.drop(columns=['Incident Date', 'Day', 'Month', 'Year', '# Injured', '# Killed'])
mass.head()
# Out:
#              State  mass_injured  mass_killed
# 959        Indiana             3            1
# 960         Oregon             4            0
# 961       Illinois             3            3
# 962        Florida             2            2
# 963  Massachusetts             5            1

# %%
#get a count of incidents by state
mass2=mass.groupby('State').size()
# create df from list created with groupby which will be merged back in
mass2_df=pd.DataFrame(mass2).reset_index().rename(columns={0: 'mass_incidents'})
mass2_df.head()
# Out:
#         State  mass_incidents
# 0     Alabama              11
# 1      Alaska               3
# 2     Arizona               4
# 3    Arkansas              13
# 4  California              39

# %%
#Groupby State and sum up the injured & killed
mass=mass.groupby('State').sum().reset_index()
mass.head()
# Out:
#         State  mass_injured  mass_killed
# 0     Alabama            37           16
# 1      Alaska             8            5
# 2     Arizona            16            4
# 3    Arkansas            48           10
# 4  California           153           37

# %%
#merge incidents with injured & killed
mass_df=mass.merge(mass2_df, left_on='State', right_on='State')
mass_df.head()
# Out:
#         State  mass_injured  mass_killed  mass_incidents
# 0     Alabama            37           16              11
# 1      Alaska             8            5               3
# 2     Arizona            16            4               4
# 3    Arkansas            48           10              13
# 4  California           153           37              39

# %% [markdown]
# ### Merge License/Ownership/Mortality with Mass Incidents

# %%
allgun=gun2.merge(mass_df, how='outer', left_on='State', right_on='State')
allgun.head()
# Out:
#           State  gun_license_ct  gun_house_pct  gun_license_ct_rank  \
# 0  Rhode Island            4887           14.8                    1
# 1      Delaware            6092           34.4                    2
# 2        Hawaii            9280           14.9                    3
# 3       Vermont            9451           50.5                    4
# 4         Maine           21396           46.8                    5
#
#    gun_house_pct_rank  gun_mort_rate  gun_deaths  gun_mort_rank  \
# 0                   3            5.1        54.0            4.0
# 1                  10           14.4       135.0           26.0
# 2                   4            3.4        50.0            1.0
# 3                  35           11.6        76.0           14.0
# 4                  28           10.4       153.0           11.0
#
#    gun_deaths_rank     Region  mass_injured  mass_killed  mass_incidents
# 0              2.0  Northeast           NaN          NaN             NaN
# 1              7.0  Northeast          11.0          3.0             3.0
# 2              1.0       West           NaN          NaN             NaN
# 3              3.0  Northeast           NaN          NaN             NaN
# 4              8.0  Northeast           1.0          3.0             1.0

# %% [markdown]
# ### Final Rankings

# %%
# Mass shootings rankings done after merge to capture NA states for 2021 mass incidents
# because NA = 0 for mass shootings,fill them before ranking
allgun['mass_incidents'] = allgun['mass_incidents'].fillna(0)
allgun['mass_injured'] = allgun['mass_injured'].fillna(0)
allgun['mass_killed'] = allgun['mass_killed'].fillna(0)
#now rank
allgun['mass_incidents_rank']=allgun['mass_incidents'].rank(method='min', na_option='top').astype(int)
allgun['mass_injured_rank']=allgun['mass_injured'].rank(method='min', na_option='top').astype(int)
allgun['mass_killed_rank']=allgun['mass_killed'].rank(method='min', na_option='top').astype(int)

allgun
# Out:
#                    State  gun_license_ct  gun_house_pct  gun_license_ct_rank  \
# 0           Rhode Island            4887           14.8                    1
# 1               Delaware            6092           34.4                    2
# 2                 Hawaii            9280           14.9                    3
# 3                Vermont            9451           50.5                    4
# 4                  Maine           21396           46.8                    5
# 5                 Alaska           28237           64.5                    6
# 6           North Dakota           30975           55.1                    7
# 7                Montana           36678           66.3                    8
# 8               Nebraska           43261           45.2                    9
# 9          Massachusetts           45138           14.7                   10
# 10         West Virginia           50963           58.5                   11
# 11                  Iowa           54178           43.6                   12
# 12          South Dakota           64666           55.3                   13
# 13                Kansas           69850           48.9                   14
# 14         New Hampshire           72433           41.1                   15
# 15  District of Columbia           74315            NaN                   16
# 16           Connecticut           74874           23.6                   17
# 17                 Idaho           76425           60.1                   18
# 18           Mississippi           80712           55.8                   19
# 19              New York           92191           19.9                   20
# 20             Wisconsin           95430           45.3                   21
# 21                Oregon           97474           50.8                   22
# 22            New Jersey          102228           14.7                   23
# 23              Oklahoma          103368           54.7                   24
# 24              Kentucky          108833           54.6                   25
# 25              Michigan          109835           40.2                   26
# 26              Missouri          113351           48.8                   27
# 27                  Utah          118408           46.8                   28
# 28                Nevada          119007           47.3                   29
# 29        South Carolina          119205           49.4                   30
# 30            New Mexico          122968           46.2                   31
# 31             Minnesota          129825           42.8                   32
# 32              Arkansas          133981           57.2                   33
# 33              Maryland          136257           30.2                   34
# 34               Wyoming          142247           66.2                   35
# 35              Illinois          144749           27.8                   36
# 36              Colorado          149382           45.1                   37
# 37             Tennessee          151536           51.6                   38
# 38             Louisiana          152061           53.1                   39
# 39               Indiana          157546           44.8                   40
# 40            Washington          165534           42.1                   41
# 41               Alabama          194920           55.5                   42
# 42                  Ohio          208661           40.0                   43
# 43        North Carolina          222166           45.8                   44
# 44               Arizona          258691           46.3                   45
# 45               Georgia          304124           49.2                   46
# 46          Pennsylvania          348167           40.7                   47
# 47            California          406360           28.3                   48
# 48              Virginia          423707           44.6                   49
# 49               Florida          518725           35.3                   50
# 50                 Texas         1006555           45.7                   51
#
#     gun_house_pct_rank  gun_mort_rate  gun_deaths  gun_mort_rank  \
# 0                    3            5.1        54.0            4.0
# 1                   10           14.4       135.0           26.0
# 22             19.0  Northeast          51.0         11.0            12.0
# 23             29.0      South           7.0          1.0             2.0
# 24             31.0      South          44.0          6.0            10.0
# 25             41.0    Midwest          75.0         21.0            21.0
# 26             40.0    Midwest          96.0         25.0            22.0
# 27             18.0       West           1.0          4.0             1.0
# 28             23.0       West          12.0          7.0             4.0
# 29             34.0      South          98.0         24.0            22.0
# 30             20.0       West          12.0          1.0             3.0
# 31             22.0    Midwest          34.0          1.0             6.0
# 32             25.0      South          48.0         10.0            13.0
# 33             27.0  Northeast          75.0         10.0            18.0
# 34              9.0       West           0.0          0.0             0.0
# 35             44.0    Midwest         297.0         42.0            68.0
# 36             32.0       West          52.0          6.0            11.0
# 37             42.0      South          85.0          9.0            19.0
# 38             38.0      South         113.0         21.0            27.0
# 39             36.0    Midwest          23.0          9.0             7.0
# 40             30.0       West          25.0          2.0             5.0
# 41             35.0      South          37.0         16.0            11.0
# 42             46.0    Midwest         111.0         22.0            25.0
# 43             43.0      South          80.0         26.0            20.0
# 44             39.0       West          16.0          4.0             4.0
# 45             47.0      South          73.0         18.0            17.0
# 46             45.0  Northeast         139.0         15.0            34.0
# 47             49.0       West         153.0         37.0            39.0
# 48             37.0      South          46.0          3.0            11.0
# 49             48.0      South         133.0         26.0            34.0
# 50             50.0      South         124.0         37.0            34.0
#
#     mass_incidents_rank  mass_injured_rank  mass_killed_rank
# 0                     1                  1                 1
# 1                    16                 18                17
# 2                     1                  1                 1
# 3                     1                  1                 1
# 4                     8                  8                17
# 5                    16                 15                22
# 6                     1                  1                 1
# 7                     1                  1                 1
# 8                    12                 17                14
# 9                    27                 26                22
# 10                   16                 12                32
# 11                   20                 21                22
# 12                    8                 10                 9
# 13                   12                 16                 1
# 14                    1                  1                 1
# 15                   27                 35                22
# 16                   25                 25                28
# 17                    8                 10                14
# 18                   36                 36                40
# 19                   49                 50                41
# 20                   29                 29                35
# 21                   12                 12                 9
# 22                   34                 33                35
# 23                   12                 12                 9
# 24                   29                 30                26
# 25                   41                 38                42
# 26                   42                 42                46
# 27                    8                  8                20
# 28                   20                 19                28
# 29                   42                 43                45
# 30                   16                 19                 9
# 31                   24                 27                 9
# 32                   35                 32                32
# 33                   38                 38                32
# 34                    1                  1                 1
# 35                   51                 51                51
# 36                   31                 34                26
# 37                   39                 41                30
# 38                   45                 45                42
# 39                   25                 23                30
# 40                   23                 24                14
# 41                   31                 28                38
# 42                   44                 44                44
# 43                   40                 40                47
# 44                   20                 21                20
# 45                   36                 37                39
# 46                   46                 48                37
# 47                   50                 49                49
# 48                   31                 31                17
# 49                   46                 47                47
# 50                   46                 46                49

# %%
# get a total of all gun rankings and rank them, proving an overall gun ranking per state
ranks=['mass_killed_rank', 'mass_injured_rank', 'mass_incidents_rank', 'gun_license_ct_rank', 'gun_house_pct_rank', 'gun_mort_rank', 'gun_deaths_rank']
allgun['gun_score']= allgun[ranks].sum(axis=1)
allgun['total_gun_rank']=allgun['gun_score'].rank(method='min', na_option='bottom').astype(int)
# 38             38.0      South         113.0         21.0            27.0
# 39             36.0    Midwest          23.0          9.0             7.0
# 40             30.0       West          25.0          2.0             5.0
# 41             35.0      South          37.0         16.0            11.0
# 42             46.0    Midwest         111.0         22.0            25.0
# 43             43.0      South          80.0         26.0            20.0
# 44             39.0       West          16.0          4.0             4.0
# 45             47.0      South          73.0         18.0            17.0
# 46             45.0  Northeast         139.0         15.0            34.0
# 47             49.0       West         153.0         37.0            39.0
# 48             37.0      South          46.0          3.0            11.0
# 49             48.0      South         133.0         26.0            34.0
# 50             50.0      South         124.0         37.0            34.0
#
#     mass_incidents_rank  mass_injured_rank  mass_killed_rank  gun_score  \
# 0                     1                  1                 1       13.0
# 1                    16                 18                17       96.0
# 2                     1                  1                 1       12.0
# 3                     1                  1                 1       59.0
# 4                     8                  8                17       85.0
# 5                    16                 15                22      162.0
# 6                     1                  1                 1       78.0
# 7                     1                  1                 1      114.0
# 8                    12                 17                14       95.0
# 9                    27                 26                22      102.0
# 10                   16                 12                32      170.0
# 11                   20                 21                22      123.0
# 12                    8                 10                 9      106.0
# 13                   12                 16                 1      128.0
# 14                    1                  1                 1       47.0
# 15                   27                 35                22      151.0
# 16                   25                 25                28      119.0
# 17                    8                 10                14      147.0
# 18                   36                 36                40      253.0
# 19                   49                 50                41      203.0
# 20                   29                 29                35      178.0
# 21                   12                 12                 9      131.0
# 22                   34                 33                35      148.0
# 23                   12                 12                 9      165.0
# 24                   29                 30                26      218.0
# 25                   41                 38                42      228.0
# 26                   42                 42                46      275.0
# 27                    8                  8                20      129.0
# 28                   20                 19                28      182.0
# 29                   42                 43                45      270.0
# 30                   16                 19                 9      165.0
# 31                   24                 27                 9      139.0
# 32                   35                 32                32      245.0
# 33                   38                 38                32      196.0
# 34                    1                  1                 1      144.0
# 35                   51                 51                51      264.0
# 36                   31                 34                26      210.0
# 37                   39                 41                30      268.0
# 38                   45                 45                42      296.0
# 39                   25                 23                30      208.0
# 40                   23                 24                14      160.0
# 41                   31                 28                38      263.0
# 42                   44                 44                44      261.0
# 43                   40                 40                47      269.0
# 44                   20                 21                20      203.0
# 45                   36                 37                39      274.0
# 46                   46                 48                37      256.0
# 47                   50                 49                49      260.0
# 48                   31                 31                17      201.0
# 49                   46                 47                47      271.0
# 50                   46                 46                49      291.0
#
#     total_gun_rank
# 0                2
# 1                8
# 2                1
# 3                4
# 4                6
# 5               23
# 6                5
# 7               11
# 8                7
# 9                9
# 10              26
# 11              13
# 12              10
# 13              14
# 14               3
# 15              21
# 16              12
# 17              19
# 18              38
# 19              31
# 20              27
# 21              16
# 22              20
# 23              24
# 24              35
# 25              36
# 26              49
# 27              15
# 28              28
# 29              46
# 30              24
# 31              17
# 32              37
# 33              29
# 34              18
# 35              43
# 36              34
# 37              44
# 38              51
# 39              33
# 40              22
# 41              42
# 42              41
# 43              45
# 44              31
# 45              48
# 46              39
# 47              40
# 48              30
# 49              47
# 50              50

# %%
allgun.to_json('json_out/guns.json', orient="records")
