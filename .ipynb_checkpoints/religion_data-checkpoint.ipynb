# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.pewresearch.org/fact-tank/2016/02/29/how-religious-is-your-state/?state=alabama')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [/Users/michaelraines/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
# /var/folders/qc/_ykx45d102d0nr51ysx4tb4h0000gn/T/ipykernel_67141/3084634327.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
# default table is states ranked by overall combined index
soup = BeautifulSoup(driver.page_source, 'lxml')
#find table on page
tables = soup.find_all('table')
#read table
overall = pd.read_html(str(tables))
# put table in dataframe to work with data
overall_df=pd.DataFrame(np.concatenate (overall))
overall_df.head()
# Out:
#                 0    1
# 0      1. Alabama  77%
# 1  1. Mississippi  77%
# 2    3. Tennessee  73%
# 3    4. Louisiana  71%
# 4     5. Arkansas  70%

# %%
#take column 0 in df split it to get name and ranking into new df
new_over= overall_df[0].str.split('.', expand=True).rename(columns={1: "State",0:'Rel_Overall_Rank'})
new_over.head()
# Out:
#   Rel_Overall_Rank         State
# 0                1       Alabama
# 1                1   Mississippi
# 2                3     Tennessee
# 3                4     Louisiana
# 4                5      Arkansas

# %%
# merge two df's together at index taking only column 1 from original table
final_over = new_over.merge(overall_df.iloc[:,[1]], how='left', left_index=True, right_index=True)
final_over = final_over.rename(columns={1: 'Rel_Overall_Pct'})
final_over.head()
# Out:
#   Rel_Overall_Rank         State Rel_Overall_Pct
# 0                1       Alabama             77%
# 1                1   Mississippi             77%
# 2                3     Tennessee             73%
# 3                4     Louisiana             71%
# 4                5      Arkansas             70%

# %%
#manually change dropdown on page to select new table to worship attendance
#format will be same as above
soup = BeautifulSoup(driver.page_source, 'lxml')
tables = soup.find_all('table')
attendance = pd.read_html(str(tables))
attendance_df=pd.DataFrame(np.concatenate (attendance))
attendance_df.head()
# Out:
#                    0    1
# 0            1. Utah  53%
# 1         2. Alabama  51%
# 2       2. Tennessee  51%
# 3     4. Mississippi  49%
# 4  5. South Carolina  47%

# %%
new_att= attendance_df[0].str.split('.', expand=True).rename(columns={0:'Rel_Att_Rank', 1: "State"})
new_att.head()
# Out:
#   Rel_Att_Rank            State
# 0            1             Utah
# 1            2          Alabama
# 2            2        Tennessee
# 3            4      Mississippi
# 4            5   South Carolina

# %%
final_attendance=new_att.merge(attendance_df.iloc[:,[1]], how='left', left_index=True, right_index=True)
final_attendance = final_attendance.rename(columns={1: 'Rel_Att_Pct'})
final_attendance.head()
# Out:
#   Rel_Att_Rank            State Rel_Att_Pct
# 0            1             Utah         53%
# 1            2          Alabama         51%
# 2            2        Tennessee         51%
# 3            4      Mississippi         49%
# 4            5   South Carolina         47%

# %%
#manually change dropdown on page to select new table to belief in God
soup = BeautifulSoup(driver.page_source, 'lxml')
tables = soup.find_all('table')
belief = pd.read_html(str(tables))
belief_df=pd.DataFrame(np.concatenate (belief))
# belief_df.head()

# %%
new_belief= belief_df[0].str.split('.', expand=True).rename(columns={0:'Rel_Belief_Rank', 1: "State"})
# new_belief.head()

# %%
final_belief=new_belief.merge(belief_df.iloc[:,[1]], how='left', left_index=True, right_index=True)
final_belief = final_belief.rename(columns={1: 'Rel_Belief_Pct'})
final_belief.head()
# Out:
#   Rel_Belief_Rank           State Rel_Belief_Pct
# 0               1         Alabama            82%
# 1               1     Mississippi            82%
# 2               3       Tennessee            78%
# 3               4   West Virginia            77%
# 4               4        Arkansas            77%

# %%
#manually change dropdown on page to select new table to importance of religion
soup = BeautifulSoup(driver.page_source, 'lxml')
tables = soup.find_all('table')
importance = pd.read_html(str(tables))
import_df=pd.DataFrame(np.concatenate (importance))
# import_df

# %%
new_import= import_df[0].str.split('.', expand=True).rename(columns={0:'Rel_Import_Rank', 1: "State"})
# new_import

# %%
final_import=new_import.merge(import_df.iloc[:,[1]], how='left', left_index=True, right_index=True)
final_import = final_import.rename(columns={1: 'Rel_Import_Pct'})
final_import.head()
# Out:
#   Rel_Import_Rank         State Rel_Import_Pct
# 0               1       Alabama            77%
# 1               2   Mississippi            74%
# 2               3     Tennessee            71%
# 3               3     Louisiana            71%
# 4               5      Arkansas            70%

# %%
#manually change dropdown on page to select new table to freq of prayer
soup = BeautifulSoup(driver.page_source, 'lxml')
tables = soup.find_all('table')
freq = pd.read_html(str(tables))
freq_df=pd.DataFrame(np.concatenate (freq))
freq_df.head()
# Out:
#                   0    1
# 0    1. Mississippi  75%
# 1        2. Alabama  73%
# 2      3. Tennessee  70%
# 3      4. Louisiana  68%
# 4  4. West Virginia  68%

# %%
new_freq= freq_df[0].str.split('.', expand=True).rename(columns={0:'Rel_Prayer_Freq_Rank', 1: "State"})
# new_freq.head()

# %%
final_freq = new_freq.merge(freq_df.iloc[:,[1]], how='left', left_index=True, right_index=True)
final_freq = final_freq.rename(columns={1: 'Rel_Freq_Prayer_Pct'})
final_freq.head()
# Out:
#   Rel_Prayer_Freq_Rank           State Rel_Freq_Prayer_Pct
# 0                    1     Mississippi                 75%
# 1                    2         Alabama                 73%
# 2                    3       Tennessee                 70%
# 3                    4       Louisiana                 68%
# 4                    4   West Virginia                 68%

# %%
merge1=final_import.merge(final_belief, how='inner', left_on='State', right_on='State')
merge2=final_attendance.merge(final_over, how='inner', left_on='State', right_on='State')

# %%
religion1=merge1.merge(merge2, how='inner', left_on='State', right_on='State')
religion=religion1.merge(final_freq, how='inner', left_on='State', right_on='State')
religion
# Out:
#    Rel_Import_Rank                  State Rel_Import_Pct Rel_Belief_Rank  \
# 0                1                Alabama            77%               1
# 1                2            Mississippi            74%               1
# 2                3              Tennessee            71%               3
# 3                3              Louisiana            71%               6
# 4                5               Arkansas            70%               4
# 5                6         South Carolina            69%               8
# 6                7          West Virginia            64%               4
# 7                7                Georgia            64%               8
# 8                7               Oklahoma            64%              11
# 9               10               Kentucky            63%               6
# 10              10                  Texas            63%              13
# 11              12         North Carolina            62%              10
# 12              13               Virginia            60%              15
# 13              14             New Mexico            59%              25
# 14              15                   Utah            58%              31
# 15              16           South Dakota            57%              13
# 16              17               Missouri            56%              12
# 17              17                   Ohio            56%              15
# 18              19               Nebraska            54%              17
# 19              20                   Iowa            53%              17
# 20              20                Florida            53%              21
# 21              20           North Dakota            53%              21
# 22              20                Indiana            53%              25
# 23              24                  Idaho            51%              28
# 24              24                Arizona            51%              28
# 25              24           Pennsylvania            51%              31
# 26              27                 Kansas            50%              17
# 27              27               Maryland            50%              21
# 28              27               Michigan            50%              25
# 29              27               Illinois            50%              31
# 30              27             New Jersey            50%              35
# 31              27   District of Columbia            50%              42
# 32              33                Wyoming            49%              17
# 33              34           Rhode Island            48%              35
# 34              35               Colorado            47%              42
# 35              35             California            47%              46
# 36              37               Delaware            46%              31
# 37              37              Minnesota            46%              39
# 38              39                 Oregon            45%              38
# 39              39               New York            45%              39
# 40              41                Montana            44%              21
# 41              41                 Hawaii            44%              28
# 42              41                 Nevada            44%              37
# 43              41              Wisconsin            44%              39
# 44              41             Washington            44%              42
# 45              46            Connecticut            42%              46
# 46              47                 Alaska            41%              42
# 47              48                  Maine            34%              48
# 48              49          New Hampshire            33%              49
# 49              49          Massachusetts            33%              51
# 50              51                Vermont            32%              50
#
#    Rel_Belief_Pct Rel_Att_Rank Rel_Att_Pct Rel_Overall_Rank Rel_Overall_Pct  \
# 0             82%            2         51%                1             77%
# 1             82%            4         49%                1             77%
# 2             78%            2         51%                3             73%
# 3             75%            6         46%                4             71%
# 4             77%           12         41%                5             70%
# 5             74%            5         47%                5             70%
# 6             77%            6         46%                7             69%
# 7             74%           10         42%                8             66%
# 8             71%            9         43%                8             66%
# 9             75%           13         39%               13             63%
# 10            69%           10         42%               11             64%
# 11            73%           13         39%               10             65%
# 12            67%            8         44%               14             61%
# 13            63%           21         36%               18             57%
# 14            61%            1         53%               11             64%
# 15            69%           21         36%               16             59%
# 16            70%           18         37%               15             60%
# 17            67%           16         38%               17             58%
# 18            66%           13         39%               22             54%
# 19            66%           21         36%               19             55%
# 20            64%           25         35%               22             54%
# 21            64%           33         33%               27             53%
# 22            63%           18         37%               22             54%
# 23            62%           25         35%               33             51%
# 24            62%           28         34%               27             53%
# 25            61%           28         34%               27             53%
# 26            66%           18         37%               19             55%
# 27            64%           35         31%               22             54%
# 28            63%           33         33%               27             53%
# 29            61%           28         34%               33             51%
# 30            60%           25         35%               19             55%
# 31            55%           44         28%               27             53%
# 32            66%           16         38%               22             54%
# 33            60%           21         36%               35             49%
# 34            55%           39         30%               41             47%
# 35            54%           35         31%               35             49%
# 36            61%           28         34%               32             52%
# 37            56%           28         34%               35             49%
# 38            57%           42         29%               39             48%
# 39            56%           42         29%               43             46%
# 40            64%           35         31%               39             48%
# 41            62%           44         28%               41             47%
# 42            59%           35         31%               35             49%
# 43            56%           47         27%               44             45%
# 44            55%           39         30%               44             45%
# 45            54%           44         28%               47             43%
# 46            55%           39         30%               44             45%
# 47            48%           49         22%               48             34%
# 48            43%           49         22%               50             33%
# 49            40%           48         23%               50             33%
# 50            41%           51         21%               48             34%
#
#    Rel_Prayer_Freq_Rank Rel_Freq_Prayer_Pct
# 0                     2                 73%
# 1                     1                 75%
# 2                     3                 70%
# 3                     4                 68%
# 4                     8                 65%
# 5                     6                 66%
# 6                     4                 68%
# 7                    10                 64%
# 8                     8                 65%
# 9                    11                 63%
# 10                   11                 63%
# 11                    6                 66%
# 12                   14                 60%
# 13                   19                 55%
# 14                   13                 61%
# 15                   17                 56%
# 16                   15                 59%
# 17                   16                 57%
# 18                   26                 52%
# 19                   35                 50%
# 20                   17                 56%
# 21                   29                 51%
# 22                   26                 52%
# 23                   35                 50%
# 24                   19                 55%
# 25                   21                 54%
# 26                   22                 53%
# 27                   29                 51%
# 28                   22                 53%
# 29                   29                 51%
# 30                   22                 53%
# 31                   29                 51%
# 32                   22                 53%
# 33                   40                 48%
# 34                   35                 50%
# 35                   29                 51%
# 36                   38                 49%
# 37                   43                 47%
# 38                   47                 45%
# 39                   40                 48%
# 40                   29                 51%
# 41                   26                 52%
# 42                   40                 48%
# 43                   45                 46%
# 44                   45                 46%
# 45                   43                 47%
# 46                   38                 49%
# 47                   50                 35%
# 48                   49                 36%
# 49                   48                 37%
# 50                   51                 33%

# %%
religion= religion[['State','Rel_Overall_Rank','Rel_Overall_Pct','Rel_Import_Rank','Rel_Import_Pct','Rel_Belief_Rank','Rel_Belief_Pct','Rel_Att_Rank',
'Rel_Att_Pct', 'Rel_Prayer_Freq_Rank', 'Rel_Freq_Prayer_Pct']]
religion
# Out:
#                     State Rel_Overall_Rank Rel_Overall_Pct Rel_Import_Rank  \
# 0                 Alabama                1             77%               1
# 1             Mississippi                1             77%               2
# 2               Tennessee                3             73%               3
# 3               Louisiana                4             71%               3
# 4                Arkansas                5             70%               5
# 5          South Carolina                5             70%               6
# 6           West Virginia                7             69%               7
# 7                 Georgia                8             66%               7
# 8                Oklahoma                8             66%               7
# 9                Kentucky               13             63%              10
# 10                  Texas               11             64%              10
# 11         North Carolina               10             65%              12
# 12               Virginia               14             61%              13
# 13             New Mexico               18             57%              14
# 14                   Utah               11             64%              15
# 15           South Dakota               16             59%              16
# 16               Missouri               15             60%              17
# 17                   Ohio               17             58%              17
# 18               Nebraska               22             54%              19
# 19                   Iowa               19             55%              20
# 20                Florida               22             54%              20
# 21           North Dakota               27             53%              20
# 22                Indiana               22             54%              20
# 23                  Idaho               33             51%              24
# 24                Arizona               27             53%              24
# 25           Pennsylvania               27             53%              24
# 26                 Kansas               19             55%              27
# 27               Maryland               22             54%              27
# 28               Michigan               27             53%              27
# 29               Illinois               33             51%              27
# 30             New Jersey               19             55%              27
# 31   District of Columbia               27             53%              27
# 32                Wyoming               22             54%              33
# 33           Rhode Island               35             49%              34
# 34               Colorado               41             47%              35
# 35             California               35             49%              35
# 36               Delaware               32             52%              37
# 37              Minnesota               35             49%              37
# 38                 Oregon               39             48%              39
# 39               New York               43             46%              39
# 40                Montana               39             48%              41
# 41                 Hawaii               41             47%              41
# 42                 Nevada               35             49%              41
# 43              Wisconsin               44             45%              41
# 44             Washington               44             45%              41
# 45            Connecticut               47             43%              46
# 46                 Alaska               44             45%              47
# 47                  Maine               48             34%              48
# 48          New Hampshire               50             33%              49
# 49          Massachusetts               50             33%              49
# 50                Vermont               48             34%              51
#
#    Rel_Import_Pct Rel_Belief_Rank Rel_Belief_Pct Rel_Att_Rank Rel_Att_Pct  \
# 0             77%               1            82%            2         51%
# 1             74%               1            82%            4         49%
# 2             71%               3            78%            2         51%
# 3             71%               6            75%            6         46%
# 4             70%               4            77%           12         41%
# 5             69%               8            74%            5         47%
# 6             64%               4            77%            6         46%
# 7             64%               8            74%           10         42%
# 8             64%              11            71%            9         43%
# 9             63%               6            75%           13         39%
# 10            63%              13            69%           10         42%
# 11            62%              10            73%           13         39%
# 12            60%              15            67%            8         44%
# 13            59%              25            63%           21         36%
# 14            58%              31            61%            1         53%
# 15            57%              13            69%           21         36%
# 16            56%              12            70%           18         37%
# 17            56%              15            67%           16         38%
# 18            54%              17            66%           13         39%
# 19            53%              17            66%           21         36%
# 20            53%              21            64%           25         35%
# 21            53%              21            64%           33         33%
# 22            53%              25            63%           18         37%
# 23            51%              28            62%           25         35%
# 24            51%              28            62%           28         34%
# 25            51%              31            61%           28         34%
# 26            50%              17            66%           18         37%
# 27            50%              21            64%           35         31%
# 28            50%              25            63%           33         33%
# 29            50%              31            61%           28         34%
# 30            50%              35            60%           25         35%
# 31            50%              42            55%           44         28%
# 32            49%              17            66%           16         38%
# 33            48%              35            60%           21         36%
# 34            47%              42            55%           39         30%
# 35            47%              46            54%           35         31%
# 36            46%              31            61%           28         34%
# 37            46%              39            56%           28         34%
# 38            45%              38            57%           42         29%
# 39            45%              39            56%           42         29%
# 40            44%              21            64%           35         31%
# 41            44%              28            62%           44         28%
# 42            44%              37            59%           35         31%
# 43            44%              39            56%           47         27%
# 44            44%              42            55%           39         30%
# 45            42%              46            54%           44         28%
# 46            41%              42            55%           39         30%
# 47            34%              48            48%           49         22%
# 48            33%              49            43%           49         22%
# 49            33%              51            40%           48         23%
# 50            32%              50            41%           51         21%
#
#    Rel_Prayer_Freq_Rank Rel_Freq_Prayer_Pct
# 0                     2                 73%
# 1                     1                 75%
# 2                     3                 70%
# 3                     4                 68%
# 4                     8                 65%
# 5                     6                 66%
# 6                     4                 68%
# 7                    10                 64%
# 8                     8                 65%
# 9                    11                 63%
# 10                   11                 63%
# 11                    6                 66%
# 12                   14                 60%
# 13                   19                 55%
# 14                   13                 61%
# 15                   17                 56%
# 16                   15                 59%
# 17                   16                 57%
# 18                   26                 52%
# 19                   35                 50%
# 20                   17                 56%
# 21                   29                 51%
# 22                   26                 52%
# 23                   35                 50%
# 24                   19                 55%
# 25                   21                 54%
# 26                   22                 53%
# 27                   29                 51%
# 28                   22                 53%
# 29                   29                 51%
# 30                   22                 53%
# 31                   29                 51%
# 32                   22                 53%
# 33                   40                 48%
# 34                   35                 50%
# 35                   29                 51%
# 36                   38                 49%
# 37                   43                 47%
# 38                   47                 45%
# 39                   40                 48%
# 40                   29                 51%
# 41                   26                 52%
# 42                   40                 48%
# 43                   45                 46%
# 44                   45                 46%
# 45                   43                 47%
# 46                   38                 49%
# 47                   50                 35%
# 48                   49                 36%
# 49                   48                 37%
# 50                   51                 33%

# %%
religion.to_json('json_out/religion.json', orient='records')
